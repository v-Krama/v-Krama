# %% [markdown]
# The CIFAR-10 dataset is a widely used benchmark dataset in the field of computer vision and machine learning. It consists of 60,000 color images, each with a resolution of 32x32 pixels, divided into 10 classes. The dataset is further split into 50,000 training images and 10,000 testing images.
#
# The 10 classes in the CIFAR-10 dataset are as follows:
#
# Airplane
# Automobile
# Bird
# Cat
# Deer
# Dog
# Frog
# Horse
# Ship
# Truck

# %% [markdown]
# # Training the model

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
import cv2

# Set random seed for reproducibility
np.random.seed(42)

# Load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize pixel values to between 0 and 1
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# One-hot encode target variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define the CNN architecture
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# Fit the model
batch_size = 64
epochs = 100

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

history = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size),
                    steps_per_epoch=X_train.shape[0] // batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 781/781 [==============================] - ETA: 0s - loss: 1.6737 - accuracy: 0.3802
# Epoch 1: val_accuracy improved from -inf to 0.53590, saving model to best_model.h5
# 781/781 [==============================] - 107s 136ms/step - loss: 1.6737 - accuracy: 0.3802 - val_loss: 1.2737 - val_accuracy: 0.5359
# Epoch 2/100
# C:\Users\bikra\.conda\envs\qwe\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 781/781 [==============================] - ETA: 0s - loss: 1.3315 - accuracy: 0.5199
# Epoch 2: val_accuracy improved from 0.53590 to 0.59040, saving model to best_model.h5
# 781/781 [==============================] - 105s 134ms/step - loss: 1.3315 - accuracy: 0.5199 - val_loss: 1.1395 - val_accuracy: 0.5904
# Epoch 3/100
# 781/781 [==============================] - ETA: 0s - loss: 1.1900 - accuracy: 0.5756
# Epoch 3: val_accuracy improved from 0.59040 to 0.64810, saving model to best_model.h5
# 781/781 [==============================] - 108s 138ms/step - loss: 1.1900 - accuracy: 0.5756 - val_loss: 0.9895 - val_accuracy: 0.6481
# Epoch 4/100
# 781/781 [==============================] - ETA: 0s - loss: 1.0934 - accuracy: 0.6116
# Epoch 4: val_accuracy improved from 0.64810 to 0.65640, saving model to best_model.h5
# 781/781 [==============================] - 113s 144ms/step - loss: 1.0934 - accuracy: 0.6116 - val_loss: 0.9836 - val_accuracy: 0.6564
# Epoch 5/100
# 781/781 [==============================] - ETA: 0s - loss: 1.0290 - accuracy: 0.6356
# Epoch 5: val_accuracy improved from 0.65640 to 0.68750, saving model to best_model.h5
# 781/781 [==============================] - 109s 140ms/step - loss: 1.0290 - accuracy: 0.6356 - val_loss: 0.8975 - val_accuracy: 0.6875
# Epoch 6/100
# 781/781 [==============================] - ETA: 0s - loss: 0.9885 - accuracy: 0.6519
# Epoch 6: val_accuracy improved from 0.68750 to 0.70780, saving model to best_model.h5
# 781/781 [==============================] - 111s 142ms/step - loss: 0.9885 - accuracy: 0.6519 - val_loss: 0.8347 - val_accuracy: 0.7078
# Epoch 7/100
# 781/781 [==============================] - ETA: 0s - loss: 0.9391 - accuracy: 0.6680
# Epoch 7: val_accuracy did not improve from 0.70780
# 781/781 [==============================] - 106s 136ms/step - loss: 0.9391 - accuracy: 0.6680 - val_loss: 0.8614 - val_accuracy: 0.7006
# Epoch 8/100
# 781/781 [==============================] - ETA: 0s - loss: 0.9174 - accuracy: 0.6797
# Epoch 8: val_accuracy improved from 0.70780 to 0.72020, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.9174 - accuracy: 0.6797 - val_loss: 0.8111 - val_accuracy: 0.7202
# Epoch 9/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8944 - accuracy: 0.6870
# Epoch 9: val_accuracy improved from 0.72020 to 0.72910, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.8944 - accuracy: 0.6870 - val_loss: 0.7794 - val_accuracy: 0.7291
# Epoch 10/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8758 - accuracy: 0.6931
# Epoch 10: val_accuracy improved from 0.72910 to 0.73440, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.8758 - accuracy: 0.6931 - val_loss: 0.7680 - val_accuracy: 0.7344
# Epoch 11/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8594 - accuracy: 0.7018
# Epoch 11: val_accuracy did not improve from 0.73440
# 781/781 [==============================] - 108s 138ms/step - loss: 0.8594 - accuracy: 0.7018 - val_loss: 0.7873 - val_accuracy: 0.7314
# Epoch 12/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8414 - accuracy: 0.7061
# Epoch 12: val_accuracy improved from 0.73440 to 0.75060, saving model to best_model.h5
# 781/781 [==============================] - 111s 142ms/step - loss: 0.8414 - accuracy: 0.7061 - val_loss: 0.7231 - val_accuracy: 0.7506
# Epoch 13/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8179 - accuracy: 0.7149
# Epoch 13: val_accuracy did not improve from 0.75060
# 781/781 [==============================] - 108s 139ms/step - loss: 0.8179 - accuracy: 0.7149 - val_loss: 0.7079 - val_accuracy: 0.7501
# Epoch 14/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8157 - accuracy: 0.7161
# Epoch 14: val_accuracy did not improve from 0.75060
# 781/781 [==============================] - 108s 139ms/step - loss: 0.8157 - accuracy: 0.7161 - val_loss: 0.7771 - val_accuracy: 0.7359
# Epoch 15/100
# 781/781 [==============================] - ETA: 0s - loss: 0.8072 - accuracy: 0.7183
# Epoch 15: val_accuracy improved from 0.75060 to 0.77200, saving model to best_model.h5
# 781/781 [==============================] - 109s 140ms/step - loss: 0.8072 - accuracy: 0.7183 - val_loss: 0.6676 - val_accuracy: 0.7720
# Epoch 16/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7943 - accuracy: 0.7224
# Epoch 16: val_accuracy did not improve from 0.77200
# 781/781 [==============================] - 105s 134ms/step - loss: 0.7943 - accuracy: 0.7224 - val_loss: 0.7068 - val_accuracy: 0.7562
# Epoch 17/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7877 - accuracy: 0.7269
# Epoch 17: val_accuracy improved from 0.77200 to 0.77540, saving model to best_model.h5
# 781/781 [==============================] - 108s 138ms/step - loss: 0.7877 - accuracy: 0.7269 - val_loss: 0.6532 - val_accuracy: 0.7754
# Epoch 18/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.7315
# Epoch 18: val_accuracy improved from 0.77540 to 0.77710, saving model to best_model.h5
# 781/781 [==============================] - 110s 141ms/step - loss: 0.7811 - accuracy: 0.7315 - val_loss: 0.6546 - val_accuracy: 0.7771
# Epoch 19/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7699 - accuracy: 0.7304
# Epoch 19: val_accuracy did not improve from 0.77710
# 781/781 [==============================] - 108s 138ms/step - loss: 0.7699 - accuracy: 0.7304 - val_loss: 0.6866 - val_accuracy: 0.7631
# Epoch 20/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7647 - accuracy: 0.7326
# Epoch 20: val_accuracy improved from 0.77710 to 0.77970, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7647 - accuracy: 0.7326 - val_loss: 0.6462 - val_accuracy: 0.7797
# Epoch 21/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7658 - accuracy: 0.7324
# Epoch 21: val_accuracy improved from 0.77970 to 0.78480, saving model to best_model.h5
# 781/781 [==============================] - 107s 136ms/step - loss: 0.7658 - accuracy: 0.7324 - val_loss: 0.6342 - val_accuracy: 0.7848
# Epoch 22/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7599 - accuracy: 0.7357
# Epoch 22: val_accuracy did not improve from 0.78480
# 781/781 [==============================] - 106s 136ms/step - loss: 0.7599 - accuracy: 0.7357 - val_loss: 0.6861 - val_accuracy: 0.7633
# Epoch 23/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7490 - accuracy: 0.7389
# Epoch 23: val_accuracy did not improve from 0.78480
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7490 - accuracy: 0.7389 - val_loss: 0.6581 - val_accuracy: 0.7800
# Epoch 24/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7524 - accuracy: 0.7365
# Epoch 24: val_accuracy did not improve from 0.78480
# 781/781 [==============================] - 108s 138ms/step - loss: 0.7524 - accuracy: 0.7365 - val_loss: 0.6679 - val_accuracy: 0.7741
# Epoch 25/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7400 - accuracy: 0.7450
# Epoch 25: val_accuracy did not improve from 0.78480
# 781/781 [==============================] - 107s 136ms/step - loss: 0.7400 - accuracy: 0.7450 - val_loss: 0.6738 - val_accuracy: 0.7729
# Epoch 26/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.7443
# Epoch 26: val_accuracy did not improve from 0.78480
# 781/781 [==============================] - 107s 136ms/step - loss: 0.7374 - accuracy: 0.7443 - val_loss: 0.6646 - val_accuracy: 0.7786
# Epoch 27/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.7461
# Epoch 27: val_accuracy improved from 0.78480 to 0.79060, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7347 - accuracy: 0.7461 - val_loss: 0.6203 - val_accuracy: 0.7906
# Epoch 28/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.7497
# Epoch 28: val_accuracy did not improve from 0.79060
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7230 - accuracy: 0.7497 - val_loss: 0.6255 - val_accuracy: 0.7861
# Epoch 29/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7501
# Epoch 29: val_accuracy did not improve from 0.79060
# 781/781 [==============================] - 106s 135ms/step - loss: 0.7221 - accuracy: 0.7501 - val_loss: 0.6979 - val_accuracy: 0.7620
# Epoch 30/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.7497
# Epoch 30: val_accuracy did not improve from 0.79060
# 781/781 [==============================] - 106s 136ms/step - loss: 0.7219 - accuracy: 0.7497 - val_loss: 0.6221 - val_accuracy: 0.7866
# Epoch 31/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7179 - accuracy: 0.7494
# Epoch 31: val_accuracy did not improve from 0.79060
# 781/781 [==============================] - 106s 136ms/step - loss: 0.7179 - accuracy: 0.7494 - val_loss: 0.6553 - val_accuracy: 0.7777
# Epoch 32/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.7517
# Epoch 32: val_accuracy improved from 0.79060 to 0.79210, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7149 - accuracy: 0.7517 - val_loss: 0.6156 - val_accuracy: 0.7921
# Epoch 33/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7060 - accuracy: 0.7535
# Epoch 33: val_accuracy did not improve from 0.79210
# 781/781 [==============================] - 107s 137ms/step - loss: 0.7060 - accuracy: 0.7535 - val_loss: 0.6738 - val_accuracy: 0.7701
# Epoch 34/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.7532
# Epoch 34: val_accuracy did not improve from 0.79210
# 781/781 [==============================] - 106s 136ms/step - loss: 0.7099 - accuracy: 0.7532 - val_loss: 0.6509 - val_accuracy: 0.7858
# Epoch 35/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7076 - accuracy: 0.7559
# Epoch 35: val_accuracy improved from 0.79210 to 0.79440, saving model to best_model.h5
# 781/781 [==============================] - 103s 132ms/step - loss: 0.7076 - accuracy: 0.7559 - val_loss: 0.6141 - val_accuracy: 0.7944
# Epoch 36/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7005 - accuracy: 0.7567
# Epoch 36: val_accuracy did not improve from 0.79440
# 781/781 [==============================] - 103s 132ms/step - loss: 0.7005 - accuracy: 0.7567 - val_loss: 0.6480 - val_accuracy: 0.7790
# Epoch 37/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7005 - accuracy: 0.7581
# Epoch 37: val_accuracy did not improve from 0.79440
# 781/781 [==============================] - 106s 136ms/step - loss: 0.7005 - accuracy: 0.7581 - val_loss: 0.6247 - val_accuracy: 0.7886
# Epoch 38/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.7606
# Epoch 38: val_accuracy improved from 0.79440 to 0.79480, saving model to best_model.h5
# 781/781 [==============================] - 103s 131ms/step - loss: 0.6954 - accuracy: 0.7606 - val_loss: 0.6036 - val_accuracy: 0.7948
# Epoch 39/100
# 781/781 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7580
# Epoch 39: val_accuracy did not improve from 0.79480
# 781/781 [==============================] - 103s 131ms/step - loss: 0.7022 - accuracy: 0.7580 - val_loss: 0.6014 - val_accuracy: 0.7947
# Epoch 40/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.7596
# Epoch 40: val_accuracy did not improve from 0.79480
# 781/781 [==============================] - 106s 136ms/step - loss: 0.6939 - accuracy: 0.7596 - val_loss: 0.6324 - val_accuracy: 0.7847
# Epoch 41/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.7599
# Epoch 41: val_accuracy did not improve from 0.79480
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6927 - accuracy: 0.7599 - val_loss: 0.6314 - val_accuracy: 0.7877
# Epoch 42/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.7626
# Epoch 42: val_accuracy did not improve from 0.79480
# 781/781 [==============================] - 106s 136ms/step - loss: 0.6897 - accuracy: 0.7626 - val_loss: 0.6283 - val_accuracy: 0.7933
# Epoch 43/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.7605
# Epoch 43: val_accuracy did not improve from 0.79480
# 781/781 [==============================] - 106s 136ms/step - loss: 0.6886 - accuracy: 0.7605 - val_loss: 0.6833 - val_accuracy: 0.7728
# Epoch 44/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.7624
# Epoch 44: val_accuracy improved from 0.79480 to 0.80850, saving model to best_model.h5
# 781/781 [==============================] - 107s 138ms/step - loss: 0.6886 - accuracy: 0.7624 - val_loss: 0.5751 - val_accuracy: 0.8085
# Epoch 45/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.7644
# Epoch 45: val_accuracy did not improve from 0.80850
# 781/781 [==============================] - 103s 132ms/step - loss: 0.6808 - accuracy: 0.7644 - val_loss: 0.6289 - val_accuracy: 0.7900
# Epoch 46/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6764 - accuracy: 0.7665
# Epoch 46: val_accuracy did not improve from 0.80850
# 781/781 [==============================] - 106s 136ms/step - loss: 0.6764 - accuracy: 0.7665 - val_loss: 0.5987 - val_accuracy: 0.8005
# Epoch 47/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6756 - accuracy: 0.7643
# Epoch 47: val_accuracy improved from 0.80850 to 0.81790, saving model to best_model.h5
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6756 - accuracy: 0.7643 - val_loss: 0.5596 - val_accuracy: 0.8179
# Epoch 48/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.7648
# Epoch 48: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 103s 132ms/step - loss: 0.6837 - accuracy: 0.7648 - val_loss: 0.6343 - val_accuracy: 0.7942
# Epoch 49/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6739 - accuracy: 0.7659
# Epoch 49: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6739 - accuracy: 0.7659 - val_loss: 0.6063 - val_accuracy: 0.7959
# Epoch 50/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6811 - accuracy: 0.7655
# Epoch 50: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6811 - accuracy: 0.7655 - val_loss: 0.5972 - val_accuracy: 0.8002
# Epoch 51/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6709 - accuracy: 0.7671
# Epoch 51: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6709 - accuracy: 0.7671 - val_loss: 0.6101 - val_accuracy: 0.7955
# Epoch 52/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6671 - accuracy: 0.7704
# Epoch 52: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 138ms/step - loss: 0.6671 - accuracy: 0.7704 - val_loss: 0.6082 - val_accuracy: 0.7978
# Epoch 53/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6729 - accuracy: 0.7666
# Epoch 53: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6729 - accuracy: 0.7666 - val_loss: 0.6292 - val_accuracy: 0.7906
# Epoch 54/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.7674
# Epoch 54: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6711 - accuracy: 0.7674 - val_loss: 0.5555 - val_accuracy: 0.8139
# Epoch 55/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6664 - accuracy: 0.7706
# Epoch 55: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 107s 137ms/step - loss: 0.6664 - accuracy: 0.7706 - val_loss: 0.5828 - val_accuracy: 0.8076
# Epoch 56/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.7710
# Epoch 56: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 118s 151ms/step - loss: 0.6637 - accuracy: 0.7710 - val_loss: 0.6340 - val_accuracy: 0.7917
# Epoch 57/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6692 - accuracy: 0.7668
# Epoch 57: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 127s 163ms/step - loss: 0.6692 - accuracy: 0.7668 - val_loss: 0.5928 - val_accuracy: 0.8042
# Epoch 58/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.7691
# Epoch 58: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 125s 160ms/step - loss: 0.6615 - accuracy: 0.7691 - val_loss: 0.6120 - val_accuracy: 0.7955
# Epoch 59/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6593 - accuracy: 0.7710
# Epoch 59: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 129s 166ms/step - loss: 0.6593 - accuracy: 0.7710 - val_loss: 0.5830 - val_accuracy: 0.8043
# Epoch 60/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6571 - accuracy: 0.7715
# Epoch 60: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 126s 161ms/step - loss: 0.6571 - accuracy: 0.7715 - val_loss: 0.5747 - val_accuracy: 0.8062
# Epoch 61/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6606 - accuracy: 0.7713
# Epoch 61: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 132s 169ms/step - loss: 0.6606 - accuracy: 0.7713 - val_loss: 0.6134 - val_accuracy: 0.7964
# Epoch 62/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6598 - accuracy: 0.7726
# Epoch 62: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 126s 161ms/step - loss: 0.6598 - accuracy: 0.7726 - val_loss: 0.6021 - val_accuracy: 0.8005
# Epoch 63/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.7725
# Epoch 63: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 127s 162ms/step - loss: 0.6563 - accuracy: 0.7725 - val_loss: 0.6076 - val_accuracy: 0.8035
# Epoch 64/100
# 781/781 [==============================] - ETA: 0s - loss: 0.6624 - accuracy: 0.7723
# Epoch 64: val_accuracy did not improve from 0.81790
# 781/781 [==============================] - 114s 147ms/step - loss: 0.6624 - accuracy: 0.7723 - val_loss: 0.5726 - val_accuracy: 0.8099
# Epoch 64: early stopping
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 72
#      64 history = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size),
#      65                     steps_per_epoch=X_train.shape[0] // batch_size,
#      66                     epochs=epochs,
#      67                     verbose=1,
#      68                     validation_data=(X_test, y_test),
#      69                     callbacks=[early_stopping, checkpoint])
#      71 # Load the best model
# ---> 72 model = load_model('best_model.keras')
#      74 # Evaluate the model
#      75 scores = model.evaluate(X_test, y_test, verbose=1)
#
# File ~\.conda\envs\qwe\lib\site-packages\keras\src\saving\saving_api.py:238, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     230     return saving_lib.load_model(
#     231         filepath,
#     232         custom_objects=custom_objects,
#     233         compile=compile,
#     234         safe_mode=safe_mode,
#     235     )
#     237 # Legacy case.
# --> 238 return legacy_sm_saving_lib.load_model(
#     239     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240 )
#
# File ~\.conda\envs\qwe\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\.conda\envs\qwe\lib\site-packages\keras\src\saving\legacy\save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at best_model.keras

# %% [markdown]
# # Evaluating the model on test data

# %%
# Load the best model
model = load_model('best_model.h5')

# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# Generate predictions
y_pred = model.predict(X_test)

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Generate classification report and confusion matrix
print(classification_report(y_true, y_pred_classes))
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5596 - accuracy: 0.8179
# Test loss: 0.5596264600753784
# Test accuracy: 0.8179000020027161
# 313/313 [==============================] - 4s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.83      1000
#            1       0.87      0.95      0.91      1000
#            2       0.79      0.72      0.76      1000
#            3       0.79      0.55      0.65      1000
#            4       0.78      0.79      0.79      1000
#            5       0.81      0.72      0.76      1000
#            6       0.76      0.91      0.83      1000
#            7       0.80      0.90      0.84      1000
#            8       0.92      0.86      0.89      1000
#            9       0.90      0.88      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.81     10000
# weighted avg       0.82      0.82      0.81     10000
#
# [[891  16  11   7  12   0   6  11  32  14]
#  [  4 954   0   0   2   0   4   1   7  28]
#  [ 64   1 724  16  63  30  61  31   7   3]
#  [ 27  10  55 554  59 108 112  51   9  15]
#  [ 16   2  41  16 792  10  68  51   3   1]
#  [ 12   3  32  78  48 721  26  69   2   9]
#  [ 10   6  25  16  11   6 913   8   4   1]
#  [ 11   1  16   8  24  17  13 896   5   9]
#  [ 77  24   8   6   4   1   3   4 856  17]
#  [ 23  78   3   2   2   0   2   4   8 878]]

# %% [markdown]
# # Visualizing training and validation history

# %%
import matplotlib.pyplot as plt

# Access the metrics from the training history
loss = history.history['loss']
accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

# Plot the training and validation history
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing model on unseen data1

# %%
#Viewing test image1 
import cv2

# Load the image
image_path = r"D:\PC-python\F-projects\Transfer learning\6_0.jpg"  # Replace with the path to your image
image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image)
plt.axis('off')  # Remove axis ticks and labels
plt.show()

# %%
#Prediction using trained model

image_width = 32
image_height = 32

# Define the CIFAR-10 class names
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Load and preprocess the new image
image_path = r"D:\PC-python\F-projects\Transfer learning\6_0.jpg"
image = cv2.imread(image_path)
image = cv2.resize(image, (32, 32))  # Resize the image to match the input shape of the model
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
image = image.astype('float32') / 255  # Normalize the image data

# Expand dimensions to match the model's input shape
image = np.expand_dims(image, axis=0)

# Make predictions on the new image
predictions = model.predict(image)

# Convert predictions to class labels
predicted_class_index = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class
print(predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Automobile

# %% [markdown]
# # Testing model on unseen data2

# %%
#Viewing test data 2 

# Load the image
image_path = r"D:\PC-python\F-projects\Transfer learning\bird-photographers.webp"  # Replace with the path to your image
image = cv2.imread(image_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image)
plt.axis('off')  # Remove axis ticks and labels
plt.show()

# %%
#prediction using model 

# Load and preprocess the new image
image_path = r"D:\PC-python\F-projects\Transfer learning\bird-photographers.webp"  # Replace with the path to your image
image = cv2.imread(image_path)
image = cv2.resize(image, (32, 32))  # Resize the image to match the input shape of the model
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
image = image.astype('float32') / 255  # Normalize the image data

# Expand dimensions to match the model's input shape
image = np.expand_dims(image, axis=0)

# Make predictions on the new image
predictions = model.predict(image)

# Convert predictions to class labels
predicted_class_index = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_index]

# Print the predicted class
print(predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Bird
